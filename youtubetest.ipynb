# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API key connection
def Api_connect():
    Api_Id="AIzaSyCs9lpR-pE0vPyGEomdqI7CIaQssj_tHJc"

    api_service_name = "youtube"
    api_version = "v3"
    youtube = build(api_service_name,api_version,developerKey=Api_Id)
    return youtube

youtube=Api_connect()

# %%
def get_channel_info(channel_id):
    request = youtube.channels().list(
                part = "snippet,contentDetails,Statistics",
                id = channel_id)
            
    response = request.execute()

    for i in range(0,len(response["items"])):
        data = dict(
                    Channel_Name = response["items"][i]["snippet"]["title"],
                    Channel_Id = response["items"][i]["id"],
                    Subscription_Count= response["items"][i]["statistics"]["subscriberCount"],
                    Views = response["items"][i]["statistics"]["viewCount"],
                    Total_Videos = response["items"][i]["statistics"]["videoCount"],
                    Channel_Description = response["items"][i]["snippet"]["description"],
                    Playlist_Id = response["items"][i]["contentDetails"]["relatedPlaylists"]["uploads"],
                    )
        return data
    


### channel links

### zebrazone - "UC6PIKnoGw7rJnND6_jdoo5w"
### micset    - "UC5EQWvy59VeHPJz8mDALPxg"
### sameeha marium - "UCaJclHt8WiaQjbv9DY2gKjg"
### irfans view - "UCnjU1FHmao9YNfPzE039YTw"
### vj siddhu vlogs - "UCJcCB-QYPIBcbKcBQOTwhiA"
### jk - "UC_HZY9d5wJ-MEiuq6vhx8hg"
### jedcal - "UCpjLVja-gdCtElYvMmvYvYQ"

# %%
channel_details = get_channel_info("UCSKCrYPdXZU8ANVoPJBXUnA") ### Zebrazone

# %%
channel_details
# Out:
# {'Channel_Name': 'Sheninth Jr',
#  'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#  'Subscription_Count': '441',
#  'Views': '4177',
#  'Total_Videos': '27',
#  'Channel_Description': 'Coding gives pleasure❤️\u200d🔥',
#  'Playlist_Id': 'UUSKCrYPdXZU8ANVoPJBXUnA'}

# %%
def get_video_ids(channel_id):
    video_ids = []
    # get Uploads playlist id
    response = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None
    
    while True:
        response = youtube.playlistItems().list( 
                                           part = 'snippet',
                                           playlistId = playlist_id, 
                                           maxResults = 50,
                                           pageToken = next_page_token).execute()
        
        for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token = response.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
videos_idss=get_video_ids("UCSKCrYPdXZU8ANVoPJBXUnA") ### zeebrazone

# %%
videos_idss
# Out:
# ['dTETv8E95lw',
#  'Hqh7FQ63u1Q',
#  'pALy4I96Yfc',
#  'Y_xP_TfeEhI',
#  'cTfyHT1y3EU',
#  'K7RNwHSPIsw',
#  'VqzLJzoyIww',
#  'l3WXUeMeqLI',
#  'NHixpF43Obk',
#  'AzpBfaTSTZs',
#  '1zGyz3zVVTs',
#  'ssbw-PL1QLo',
#  'upCqlcJzBXM',
#  '9gqhMhKn_IE',
#  'RKVtGp70mhQ',
#  'pKHQFX7pBoA',
#  '5cDgoFyLck0',
#  'j3SB0goW-pc',
#  'yvIN1FDu8io',
#  '0Z2JnLNm_5w',
#  '1ZbmxysnRPI',
#  '5GEhN7gJjPk',
#  'j61Jeqp_9Gc',
#  'k4MXTHwCg_4',
#  '_l8H55qM1a4',
#  'taCYyfk9_mc',
#  'vpZK7vA9aaE']

# %%
#get video information
def get_video_info(video_ids):

    video_data = []

    for video_id in video_ids:
        request = youtube.videos().list(
                    part="snippet,contentDetails,statistics",
                    id= video_id)
        response = request.execute()

        for item in response["items"]:
            data = dict(Channel_Name = item['snippet']['channelTitle'],
                        Channel_Id = item['snippet']['channelId'],
                        Video_Id = item['id'],
                        Title = item['snippet']['title'],
                        Tags = item['snippet'].get('tags'),
                        Thumbnail = item['snippet']['thumbnails']['default']['url'],
                        Description = item['snippet']['description'],
                        Published_Date = item['snippet']['publishedAt'],
                        Duration = item['contentDetails']['duration'],
                        Views = item['statistics']['viewCount'],
                        Likes = item['statistics'].get('likeCount'),
                        Comments = item['statistics'].get('commentCount'),
                        Favorite_Count = item['statistics']['favoriteCount'],
                        Definition = item['contentDetails']['definition'],
                        Caption_Status = item['contentDetails']['caption']
                        )
            video_data.append(data)
    return video_data

# %%
vid_info = get_video_info(videos_idss) ### zebrazone

# %%
vid_info
# Out:
# [{'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'dTETv8E95lw',
#   'Title': 'React in 30 Seconds | Tamil #shorts #reactjs #react  #education #programming',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/dTETv8E95lw/default.jpg',
#   'Description': 'In this video We will se about What is react & Why Is It So Popular?\n\n#reactjs #shorts #coding',
#   'Published_Date': '2024-06-25T01:30:15Z',
#   'Duration': 'PT33S',
#   'Views': '2',
#   'Likes': '3',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'Hqh7FQ63u1Q',
#   'Title': 'Best way to learn Data Structures and Algorithm | Tamil | Roadmap',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Hqh7FQ63u1Q/default.jpg',
#   'Description': "Mastering Data Structures and Algorithms (DSA) Roadmap | Learn to Code\n\nIn this video, we'll dive into a comprehensive roadmap to master Data Structures and Algorithms (DSA) for beginners and intermediate programmers alike. Whether you're preparing for coding interviews, looking to enhance your problem-solving skills, or aiming to excel in competitive programming, this roadmap will guide you step-by-step through the essential concepts and techniques.\n\n📌 Topics Covered:\n\nIntroduction to DSA and its importance\nEssential data structures: Arrays, Linked Lists, Stacks, Queues, Trees, Graphs, Hash Tables, etc.\nFundamental algorithms: Sorting, Searching, Recursion, Dynamic Programming, Graph algorithms, etc.\nPractical tips for effective learning and implementation\nResources and platforms for practicing DSA problems\nHow to approach coding challenges and interviews\nBy following this roadmap, you'll build a strong foundation in DSA, improve your problem-solving skills, and gain confidence in tackling complex coding problems. Whether you're a student, a software engineer, or someone transitioning into tech, mastering DSA is crucial for advancing your programming career.\n\nChapters:\n0:00 - Prerequisite\n0:34 - Data Structure \n1:10 - Algorithm\n\nGithub : https://github.com/sheninthjr\nLinkedIn : https://linkedin.com/in/sheninthjr\nTwitter : https://twitter.com/sheninth_jr23\n\n#datastructures #algorithm  #programming #leetcode  #codinginterview  #techcareer #coding",
#   'Published_Date': '2024-06-24T10:30:07Z',
#   'Duration': 'PT2M15S',
#   'Views': '72',
#   'Likes': '14',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'pALy4I96Yfc',
#   'Title': 'Two Sum Problem | Leetcode 1 | Tamil | Easy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/pALy4I96Yfc/default.jpg',
#   'Description': 'One of the most famous simple problems in the data structures and algorithm.This problem is solved using HashMap.\n\nProblem Link : https://leetcode.com/problems/two-sum/description\n\nChapters:\n0:00 - Problem Statement\n1:18 - Drawing Explanation\n2:11 - Math Formula\n3:27 - Coding\n\nGithub : https://github.com/sheninthjr\nTwitter : https://twitter.com/sheninth_jr23\nLinkedIn : https://www.linkedin.com/in/sheninthjr\nWebsite : https://www.sheninthjr.com\n\n#datastructures #leetcode #python #twosum #coding #array #hashmap #dsa #tamil',
#   'Published_Date': '2024-06-23T10:30:07Z',
#   'Duration': 'PT4M58S',
#   'Views': '137',
#   'Likes': '13',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'Y_xP_TfeEhI',
#   'Title': 'Creating an basic Nodejs backend for User Authentication',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Y_xP_TfeEhI/default.jpg',
#   'Description': 'Creating a basic Express.js backend involves setting up a server-side application using the Express.js framework, which is a fast, unopinionated, and minimalist web framework for Node.js. With Express.js, developers can easily handle routes, HTTP requests, middleware, and more to build powerful server-side applications. The process typically includes installing Express.js, setting up the server, defining routes, handling requests and responses, integrating middleware for additional functionality, and managing dependencies. By following best practices and leveraging the flexibility of Express.js, developers can efficiently build scalable and robust backend systems to support various web applications and APIs.\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#expressjs #nodejs #javascript #typescript #mernstack',
#   'Published_Date': '2024-05-20T10:30:19Z',
#   'Duration': 'PT5M39S',
#   'Views': '50',
#   'Likes': '7',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'cTfyHT1y3EU',
#   'Title': 'How to create a basic Express Js backend?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/cTfyHT1y3EU/default.jpg',
#   'Description': 'Creating a basic Express.js backend involves setting up a server-side application using the Express.js framework, which is a fast, unopinionated, and minimalist web framework for Node.js. With Express.js, developers can easily handle routes, HTTP requests, middleware, and more to build powerful server-side applications. The process typically includes installing Express.js, setting up the server, defining routes, handling requests and responses, integrating middleware for additional functionality, and managing dependencies. By following best practices and leveraging the flexibility of Express.js, developers can efficiently build scalable and robust backend systems to support various web applications and APIs.\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#expressjs #nodejs #javascript #typescript #mernstack',
#   'Published_Date': '2024-04-19T12:30:23Z',
#   'Duration': 'PT3M5S',
#   'Views': '44',
#   'Likes': '7',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'K7RNwHSPIsw',
#   'Title': 'What are Packages? Understanding the package.json file?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/K7RNwHSPIsw/default.jpg',
#   'Description': "In Node.js, the package.json file is a crucial component of any project. It serves multiple purposes:\n\n1) Metadata: It contains metadata about the project such as the project's name, version, description, author, and license.\n2) Dependencies: One of the most important roles of package.json is to list all the dependencies required by the project. These dependencies can be libraries or frameworks that your project relies on to function properly.\n3) Scripts: It can also include scripts that define various tasks such as running tests, building the project, or starting the application. These scripts can be executed via the npm (Node Package Manager) command-line interface.\n4) Configuration: You can specify various configuration options for your project in the package.json file. This could include things like the entry point of your application, environment variables, or any other custom configurations.\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs #javascript #typescript #mernstack #expressjs #npm",
#   'Published_Date': '2024-04-18T12:30:18Z',
#   'Duration': 'PT2M50S',
#   'Views': '65',
#   'Likes': '8',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'VqzLJzoyIww',
#   'Title': 'What is Status Code?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/VqzLJzoyIww/default.jpg',
#   'Description': "An HTTP status code is a message a website 's server sends to the browser to indicate whether or not that request can be fulfilled.\n\nHTTP response status codes indicate whether a specific HTTP request has been successfully completed. Responses are grouped in five classes:\n\nInformational responses (100 – 199)\nSuccessful responses (200 – 299)\nRedirection messages (300 – 399)\nClient error responses (400 – 499)\nServer error responses (500 – 599)\n\nFor more details:   https://developer.mozilla.org/en-US/docs/Web/HTTP/Status\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs #javascript #status #code #typescript #coding",
#   'Published_Date': '2024-04-16T10:30:16Z',
#   'Duration': 'PT1M56S',
#   'Views': '66',
#   'Likes': '10',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'l3WXUeMeqLI',
#   'Title': "What are Routes? How the data's are passed on the routes?",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/l3WXUeMeqLI/default.jpg',
#   'Description': 'Routing in Node refers to the process of determining how an application responds to client requests to different endpoints (URLs). In a web application, these endpoints typically correspond to different pages or functionalities within the application.\n\n#javascript #typescript #nodejs #mernstack #programming',
#   'Published_Date': '2024-04-15T10:30:07Z',
#   'Duration': 'PT2M47S',
#   'Views': '61',
#   'Likes': '9',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'NHixpF43Obk',
#   'Title': 'What is Postman? How does it help the developers before creating the frontend?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/NHixpF43Obk/default.jpg',
#   'Description': 'Discover how Postman revolutionizes the way you build and use APIs, simplifying every stage of the API lifecycle. From design to testing, documentation, and collaboration, Postman empowers you to create superior APIs with efficiency and ease. Join us to explore the transformative potential of Postman for accelerating API development and collaboration.\n\nPostman: https://www.postman.com/downloads/\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#postman #nodejs  #javascript #typescript #mernstack #mern',
#   'Published_Date': '2024-04-14T10:30:07Z',
#   'Duration': 'PT1M10S',
#   'Views': '46',
#   'Likes': '8',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'AzpBfaTSTZs',
#   'Title': 'What is Express Js?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/AzpBfaTSTZs/default.jpg',
#   'Description': 'Express.js is a minimalist web application framework for Node.js. It provides a robust set of features to develop web and mobile applications. With its lightweight, flexible architecture, and vast ecosystem of plugins, Express.js simplifies the process of building server-side applications.\n\nExpress.js allows developers to define routes, handle HTTP requests and responses, manage middleware, and render dynamic content with ease. It follows the middleware pattern, which enables developers to plug in custom functionality into the request/response processing pipeline.\n\nOverall, Express.js is widely used for building APIs (Application Programming Interfaces) and web servers, offering a streamlined development experience for Node.js applications.\n\n#expressjs #nodejs #javascript #typescript #mongodb #backend #mernstack #react #coding',
#   'Published_Date': '2024-04-13T10:30:07Z',
#   'Duration': 'PT1M5S',
#   'Views': '59',
#   'Likes': '13',
#   'Comments': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '1zGyz3zVVTs',
#   'Title': 'What is async/await? Why it is used?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1zGyz3zVVTs/default.jpg',
#   'Description': "Discover the power of async/await in JavaScript as we delve into the world of asynchronous programming. In this video, we break down the concepts of async and await, exploring why they are essential tools for modern developers. With clear explanations and practical examples, you'll learn how async/await simplifies asynchronous code, making it more readable and easier to manage. Whether you're new to asynchronous programming or looking to deepen your understanding, this video is your guide to mastering async/await and harnessing its full potential in your projects.\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs #javascript  #typescript #mernstack #coding #programming #mernproject",
#   'Published_Date': '2024-03-26T10:30:07Z',
#   'Duration': 'PT1M32S',
#   'Views': '54',
#   'Likes': '10',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'ssbw-PL1QLo',
#   'Title': 'What are the important request types? What is the difference between them?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ssbw-PL1QLo/default.jpg',
#   'Description': "In the realm of digital communication and information exchange, understanding the various types of requests is crucial. From HTTP requests in web development to interpersonal requests in everyday interactions, each type carries its own significance and impact. Join us as we delve into the essential request types, uncovering their nuances and importance in different contexts. Whether you're a developer seeking to optimize performance or an individual navigating social dynamics, this exploration will shed light on the fundamental nature of requests and their role in shaping our interactions and experiences\n\nSlides: https://slides.com/sheninthjr/deck-8b631c\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs #javascript #typescript #coding #mernstack #programming",
#   'Published_Date': '2024-03-25T10:30:07Z',
#   'Duration': 'PT1M45S',
#   'Views': '62',
#   'Likes': '12',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'upCqlcJzBXM',
#   'Title': 'What is Nodejs? Why programmers prefer to use Nodejs over other backend languages?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/upCqlcJzBXM/default.jpg',
#   'Description': "Discover the power of Node.js and why it has become the go-to option for developers worldwide. In this video, we delve into the fundamentals of Node.js, exploring its architecture, key features, and advantages over other backend languages. Whether you're a seasoned developer or just starting out, understanding Node.js is essential in today's tech landscape. Join us as we unravel the mysteries behind Node.js and uncover why it's the preferred framework for building scalable, efficient, and high-performance web applications.\n\nSlides: https://slides.com/sheninthjr/deck-8d8339\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs #typescript #javascript #mernstack #coding #programming #opensource #mongodb",
#   'Published_Date': '2024-03-24T10:30:07Z',
#   'Duration': 'PT2M43S',
#   'Views': '90',
#   'Likes': '15',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '9gqhMhKn_IE',
#   'Title': 'Mastering Node.js: A Comprehensive Guide for 2024',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/9gqhMhKn_IE/default.jpg',
#   'Description': "Embark on a transformative journey towards mastery with our Node.js 10X Developer Roadmap! Whether you're just starting out or looking to level up your skills, this roadmap provides a clear path to success in the world of Node.js development. From mastering the fundamentals of JavaScript to diving deep into asynchronous programming, building robust APIs, and exploring advanced concepts, each step is meticulously laid out to empower you to become a highly proficient Node.js developer. Join us on this exciting adventure and unlock your full potential as a developer with Node.js! \n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#nodejs  #mernstack #javascript #typescript  #10XDeveloper",
#   'Published_Date': '2024-03-22T10:30:07Z',
#   'Duration': 'PT1M8S',
#   'Views': '159',
#   'Likes': '14',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'RKVtGp70mhQ',
#   'Title': 'How to containerize your nodejs backend using docker? #shorts  #nodejs #typescript #mernstack',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/RKVtGp70mhQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-03-21T02:06:39Z',
#   'Duration': 'PT44S',
#   'Views': '143',
#   'Likes': '21',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'pKHQFX7pBoA',
#   'Title': 'From Zero to Hero: Animate anything easily with GSAP✨ #shorts #gsap #animation #animationvideo',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/pKHQFX7pBoA/default.jpg',
#   'Description': "Dive into the world of web animation with this mesmerizing showcase using GSAP (GreenSock Animation Platform). Watch as websites come to life with fluid motion and seamless transitions, all made possible by the power of GSAP. Whether you're a beginner or a seasoned web developer, get inspired and learn how to breathe life into your digital creations with GSAP! Don't miss out on this captivating journey through the art of web animation.\n#shorts #gsap #animation #styling #trending",
#   'Published_Date': '2024-03-20T01:30:31Z',
#   'Duration': 'PT39S',
#   'Views': '264',
#   'Likes': '26',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '5cDgoFyLck0',
#   'Title': 'Mastering Git: How to Create Repositories & Push Code Using Terminal!💡🔥',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/5cDgoFyLck0/default.jpg',
#   'Description': "Unlock the full potential of Git with our step-by-step guide to creating repositories and pushing code directly from the terminal. Dive deep into the core principles of version control as we demonstrate the seamless integration of Git into your workflow. From initializing repositories to committing changes and pushing them to remote repositories, this tutorial covers it all. Whether you're a seasoned developer looking to enhance your efficiency or a newcomer eager to grasp the fundamentals, this video provides invaluable insights and practical tips to accelerate your journey towards Git mastery. Join us and revolutionize your approach to collaborative software development today!\n\nGithub Link: https://github.com/sheninthjr/rollup\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#github #typescript #nodejs  #programming #opensource #versioncontrol #coding \n#javascript",
#   'Published_Date': '2024-03-19T01:30:02Z',
#   'Duration': 'PT1M25S',
#   'Views': '419',
#   'Likes': '34',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'j3SB0goW-pc',
#   'Title': 'How does docker reduce the pain of the programmers?🤔💭#shorts #docker #typescript #nodejs',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/j3SB0goW-pc/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-03-18T02:25:12Z',
#   'Duration': 'PT40S',
#   'Views': '147',
#   'Likes': '29',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'yvIN1FDu8io',
#   'Title': 'Building Animated Landing Page with GSAP and Next.js | LCS',
#   'Tags': ['nextjs', 'react', 'typescript', 'gsap', 'tailwindcss', 'css'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yvIN1FDu8io/default.jpg',
#   'Description': 'Join us for a live coding session as we build an animated landing page using GSAP and Next.js. Follow along as we create captivating animations to enhance user experience and engagement. Perfect for developers of all levels looking to add dynamic elements to their web projects. Tune in and level up your animation skills!\n\nGithub: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#typescript #nextjs14 #live #coding #react #gsap #tailwindcss  #github #vscode #npm #programming #programmer',
#   'Published_Date': '2024-03-17T18:44:32Z',
#   'Duration': 'PT15M30S',
#   'Views': '162',
#   'Likes': '9',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '0Z2JnLNm_5w',
#   'Title': 'Building a MERN Stack Application with TypeScript | LCS Part - II',
#   'Tags': ['react',
#    'typescript',
#    'nodejs',
#    'express',
#    'mongodb',
#    'coding',
#    'mern',
#    'full-stack',
#    'vscode'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0Z2JnLNm_5w/default.jpg',
#   'Description': "Join us for an exciting live coding session where we dive into the world of full-stack development using the MERN (MongoDB, Express.js, React, Node.js) stack along with TypeScript. Whether you're a beginner or an experienced developer looking to expand your skills, this stream is perfect for you.\n\nIn this session, we'll start from scratch and walk through the process of building a basic MERN stack application. From setting up our development environment to deploying the application, you'll learn the ins and outs of each component of the stack.\n\nHere's what you can expect:\n\nSetting up MongoDB: We'll start by configuring a MongoDB database to store our application data.\nCreating an Express.js Server: Learn how to set up a server using Express.js to handle HTTP requests and responses.\nBuilding a React Frontend: Dive into building the frontend of our application using React, a powerful JavaScript library for building user interfaces.\nIntegrating with Node.js: Connect the frontend and backend by leveraging Node.js to handle server-side logic.\nImplementing TypeScript: Explore the benefits of using TypeScript for static typing and how it enhances the development experience.\nDeploying the Application: Learn how to deploy our MERN stack application to a hosting platform for the world to see.\n\nWhether you're interested in learning about MERN stack development, TypeScript, or simply enjoy live coding sessions, this is an opportunity to enhance your skills and ask questions in real-time.\n\nDon't miss out on this chance to level up your development skills and join us live as we build a MERN stack application with TypeScript! Hit the subscribe button and turn on notifications to be notified when we go live. See you there!\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#react #typescript #nodejs #expressjs #mongodb #mernstack #mernproject  #opensource #coding #codinglife #programming #codingchallenge #codingtutorial #program #programmer #vercel #npm",
#   'Published_Date': '2024-03-17T07:06:44Z',
#   'Duration': 'PT35M58S',
#   'Views': '294',
#   'Likes': '19',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '1ZbmxysnRPI',
#   'Title': 'What is Docker? #shorts #docker #nodejs #typescript',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1ZbmxysnRPI/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-03-17T02:59:41Z',
#   'Duration': 'PT38S',
#   'Views': '152',
#   'Likes': '37',
#   'Comments': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '5GEhN7gJjPk',
#   'Title': 'Transforming React Components into NPM Packages: TypeScript + Rollup',
#   'Tags': ['react', 'rollupjs', 'typescript', 'npm', 'npmpackage', 'babel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/5GEhN7gJjPk/default.jpg',
#   'Description': "Dive into the world of modern web development with our comprehensive tutorial series! Learn how to convert React components into reusable NPM packages using TypeScript and Rollup. Follow along step-by-step as we navigate the entire process, from development to deployment.\n\nUnlock the potential of TypeScript's strong typing system to enhance code robustness and maintainability. Harness the efficiency of Rollup to package your components efficiently for distribution via the NPM registry.\n\nWhether you're a seasoned developer looking to streamline your workflow or a newcomer eager to master the latest tools and techniques, our tutorials have something for everyone.\n\nSubscribe now and embark on a journey of discovery, empowering yourself to create professional-grade software components for the broader JavaScript community!\n\nGithub Link: https://github.com/sheninthjr/rollup\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#React #TypeScript #Rollup #NPM #JavaScript #WebDevelopment #npmpackage #npmmodule #react #javascript #opensource #program #coding #programming",
#   'Published_Date': '2024-03-16T03:54:24Z',
#   'Duration': 'PT4M52S',
#   'Views': '587',
#   'Likes': '56',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'j61Jeqp_9Gc',
#   'Title': 'Building a MERN Stack Application with TypeScript | LCS',
#   'Tags': ['react',
#    'typescript',
#    'nodejs',
#    'express',
#    'mongodb',
#    'coding',
#    'mern',
#    'full-stack',
#    'vscode'],
#   'Thumbnail': 'https://i.ytimg.com/vi/j61Jeqp_9Gc/default.jpg',
#   'Description': "Join us for an exciting live coding session where we dive into the world of full-stack development using the MERN (MongoDB, Express.js, React, Node.js) stack along with TypeScript. Whether you're a beginner or an experienced developer looking to expand your skills, this stream is perfect for you.\n\nIn this session, we'll start from scratch and walk through the process of building a basic MERN stack application. From setting up our development environment to deploying the application, you'll learn the ins and outs of each component of the stack.\n\nHere's what you can expect:\n\nSetting up MongoDB: We'll start by configuring a MongoDB database to store our application data.\nCreating an Express.js Server: Learn how to set up a server using Express.js to handle HTTP requests and responses.\nBuilding a React Frontend: Dive into building the frontend of our application using React, a powerful JavaScript library for building user interfaces.\nIntegrating with Node.js: Connect the frontend and backend by leveraging Node.js to handle server-side logic.\nImplementing TypeScript: Explore the benefits of using TypeScript for static typing and how it enhances the development experience.\nDeploying the Application: Learn how to deploy our MERN stack application to a hosting platform for the world to see.\n\nWhether you're interested in learning about MERN stack development, TypeScript, or simply enjoy live coding sessions, this is an opportunity to enhance your skills and ask questions in real-time.\n\nDon't miss out on this chance to level up your development skills and join us live as we build a MERN stack application with TypeScript! Hit the subscribe button and turn on notifications to be notified when we go live. See you there!\n\nGithub Link: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nTwitter: https://twitter.com/sheninth_jr23\nInstagram: https://instagram.com/sheninthjr\nWebsite Link: https://www.sheninthjr.com\n\n#react #typescript #nodejs #expressjs #mongodb #mernstack #mernproject  #opensource #coding #codinglife #programming #codingchallenge #codingtutorial #program #programmer #vercel #npm",
#   'Published_Date': '2024-03-15T20:42:04Z',
#   'Duration': 'PT2H8M16S',
#   'Views': '157',
#   'Likes': '22',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'k4MXTHwCg_4',
#   'Title': 'First Time Streaming on YouTube: Testing the Waters! LCS',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/k4MXTHwCg_4/default.jpg',
#   'Description': "Welcome to my very first YouTube live stream! Join me as I dip my toes into the world of streaming and ensure that everything is running smoothly before diving into the exciting content ahead.\n\nDuring this stream, I'll be checking all the technical aspects to make sure everything is working seamlessly. From audio levels to video quality, and ensuring smooth transitions, we'll make sure every detail is perfect for our future broadcasts.\n\nWhether you're here to offer support, share tips, or simply hang out and chat, your presence is greatly appreciated as I embark on this new adventure. Feel free to drop by and say hello!\n\nDon't forget to hit the notification bell and subscribe to my channel to stay updated on future streams and content. I can't wait to share more exciting moments with you all in the near future!\n\nLet's make this first stream a memorable one as we test the waters together and pave the way for many more to come. See you there! \n\nGithub: https://github.com/sheninthjr\nLinkedIn: https://www.linkedin.com/in/sheninthjr\nWebsite: https://www.sheninthjr.com",
#   'Published_Date': '2024-03-14T07:43:51Z',
#   'Duration': 'PT1H1M59S',
#   'Views': '83',
#   'Likes': '18',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': '_l8H55qM1a4',
#   'Title': 'JrCodeEditor: Empowering JavaScript Developers with Customization.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_l8H55qM1a4/default.jpg',
#   'Description': 'Explore the world of JavaScript coding with JrCodeEditor – your go-to, highly customizable code editor. This video showcases the features and capabilities that make JrCodeEditor the ultimate tool for JavaScript developers. Dive into a personalized coding experience, enhanced syntax highlighting, and a user-friendly interface. Elevate your coding journey with JrCodeEditor and unlock new levels of productivity. Subscribe now for the latest updates and tutorials!\n\nTry it out now: https://jrcodeeditor.vercel.app\nGithub: https://github.com/sheninthjr/JrCodeEditor\n\n#nextjs14 #typescript #tailwindcss #recoil #opensource #vercel',
#   'Published_Date': '2024-01-25T12:57:32Z',
#   'Duration': 'PT25S',
#   'Views': '154',
#   'Likes': '20',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'taCYyfk9_mc',
#   'Title': 'CodeJr: Leetcode clone using Nextjs and Tailwind for elevating your DSA skills.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/taCYyfk9_mc/default.jpg',
#   'Description': 'CodeJr, a sophisticated coding platform meticulously designed for mastering Data Structures and Algorithms using JavaScript.\n\nKey Features:\n1.Next.js 14 and TypeScript: Cutting-edge technologies to keep you at the forefront of web development.\n2.DSA Mastery: Tackle Data Structures and Algorithms problems efficiently, enhancing your problem-solving skills.\n3.Interactive Coding Environment: Write, test, and debug your code seamlessly within the platform.\n4.Web-Based Learning: Access CodeJr from anywhere, anytime – no installations required!\n\nGitHub: https://github.com/sheninthjr/CodeJr\nTry it out now: https://code-jr.vercel.app\n\n#nextjs14  #opensource #tailwindcss #dsa #datastructures #datastructuresandalgorithms #tailwindcss #problems #javascript #typescript',
#   'Published_Date': '2024-01-20T10:50:52Z',
#   'Duration': 'PT52S',
#   'Views': '174',
#   'Likes': '17',
#   'Comments': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Sheninth Jr',
#   'Channel_Id': 'UCSKCrYPdXZU8ANVoPJBXUnA',
#   'Video_Id': 'vpZK7vA9aaE',
#   'Title': 'How to Integrate Recoil with Nextjs14?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/vpZK7vA9aaE/default.jpg',
#   'Description': 'Enhance the state management capabilities of your Next.js 14 application by seamlessly incorporating Recoil. Begin by installing Recoil using npm or yarn. Establish a dedicated Recoil store, defining atoms and selectors. Integrate the RecoilRoot component within _app.js, encapsulating your application. Utilize useRecoilState or useRecoilValue hooks for efficient component interaction, ensuring optimal state management.\n\n#nextjs14 #typescript #recoil',
#   'Published_Date': '2024-01-09T13:20:00Z',
#   'Duration': 'PT3M56S',
#   'Views': '524',
#   'Likes': '23',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
#get comment information
def get_comment_info(video_ids):
        Comment_Information = []
        try:
                for video_id in video_ids:

                        request = youtube.commentThreads().list(
                                part = "snippet",
                                videoId = video_id,
                                maxResults = 50
                                )
                        response5 = request.execute()
                        
                        for item in response5["items"]:
                                comment_information = dict(
                                        Comment_Id = item["snippet"]["topLevelComment"]["id"],
                                        Video_Id = item["snippet"]["videoId"],
                                        Comment_Text = item["snippet"]["topLevelComment"]["snippet"]["textOriginal"],
                                        Comment_Author = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                                        Comment_Published = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"])

                                Comment_Information.append(comment_information)
        except:
                pass
                
        return Comment_Information

# %%
comment_details = get_comment_info(videos_idss) ### zebrazone

# %%
comment_details
# Out:
# [{'Comment_Id': 'Ugzv0OxdaqQty4CpXgJ4AaABAg',
#   'Video_Id': 'Hqh7FQ63u1Q',
#   'Comment_Text': 'Niceee',
#   'Comment_Author': '@arjun-gc9hu',
#   'Comment_Published': '2024-06-24T11:57:44Z'},
#  {'Comment_Id': 'UgzH9mh1yYOxGugaz7N4AaABAg',
#   'Video_Id': 'Hqh7FQ63u1Q',
#   'Comment_Text': '✨ clear explanation bro',
#   'Comment_Author': '@monesh.s6001',
#   'Comment_Published': '2024-06-24T10:58:19Z'},
#  {'Comment_Id': 'UgxvAzY2r_JC1ilvnLB4AaABAg',
#   'Video_Id': 'pALy4I96Yfc',
#   'Comment_Text': 'Broo ipdiye niraiyaa leetcode problems ku solutions kudunga bro pls useful ah irukum 🙏🏻',
#   'Comment_Author': '@unknownuser64883',
#   'Comment_Published': '2024-06-24T10:26:30Z'},
#  {'Comment_Id': 'UgyI3OGsDFVCI5lC15d4AaABAg',
#   'Video_Id': 'pALy4I96Yfc',
#   'Comment_Text': 'I need dsa roadmap bro..✨',
#   'Comment_Author': '@monesh.s6001',
#   'Comment_Published': '2024-06-24T06:10:47Z'},
#  {'Comment_Id': 'UgwLI76lKrdbvBejXL54AaABAg',
#   'Video_Id': 'pALy4I96Yfc',
#   'Comment_Text': 'Very much useful and understandable 👍',
#   'Comment_Author': '@arjun-gc9hu',
#   'Comment_Published': '2024-06-23T15:20:33Z'},
#  {'Comment_Id': 'UgzZl1Kz05xvygQxbBp4AaABAg',
#   'Video_Id': 'VqzLJzoyIww',
#   'Comment_Text': 'next topic pls upload  bro',
#   'Comment_Author': '@karnankarnan516',
#   'Comment_Published': '2024-04-16T10:37:51Z'},
#  {'Comment_Id': 'UgyOig3WQamsQCuPH754AaABAg',
#   'Video_Id': 'AzpBfaTSTZs',
#   'Comment_Text': '✨',
#   'Comment_Author': '@monesh.s6001',
#   'Comment_Published': '2024-04-13T12:15:02Z'},
#  {'Comment_Id': 'UgxT8-MOwmeGmzuIDod4AaABAg',
#   'Video_Id': '5cDgoFyLck0',
#   'Comment_Text': 'very helpful, start a small playlist for whole git commands and github',
#   'Comment_Author': '@dasarimanoj3086',
#   'Comment_Published': '2024-03-20T08:40:06Z'},
#  {'Comment_Id': 'UgyTLfhHHy0xZ_LfBMJ4AaABAg',
#   'Video_Id': '5cDgoFyLck0',
#   'Comment_Text': 'Very helpful 💚',
#   'Comment_Author': '@arunraja1821',
#   'Comment_Published': '2024-03-19T15:43:00Z'},
#  {'Comment_Id': 'UgwNUQj_x6OhkI38z4R4AaABAg',
#   'Video_Id': 'yvIN1FDu8io',
#   'Comment_Text': 'If you want the code of this project please comment it below? 👇',
#   'Comment_Author': '@sheninthjr',
#   'Comment_Published': '2024-03-17T18:51:23Z'},
#  {'Comment_Id': 'Ugy12u2UK29VlDBofjB4AaABAg',
#   'Video_Id': '1ZbmxysnRPI',
#   'Comment_Text': 'Thank you for this  video bro...',
#   'Comment_Author': '@Sriniha_07',
#   'Comment_Published': '2024-03-17T05:04:17Z'},
#  {'Comment_Id': 'UgybNXFxJwskv_Tbp2V4AaABAg',
#   'Video_Id': '5GEhN7gJjPk',
#   'Comment_Text': 'Nice🔥🔥',
#   'Comment_Author': '@m.j.kawsheka6341',
#   'Comment_Published': '2024-03-16T13:05:46Z'},
#  {'Comment_Id': 'UgwHyBeHDtsomvYzOKl4AaABAg',
#   'Video_Id': '5GEhN7gJjPk',
#   'Comment_Text': 'Awesome',
#   'Comment_Author': '@KUKOOO',
#   'Comment_Published': '2024-03-16T10:23:32Z'},
#  {'Comment_Id': 'UgwtRhtI-2jF_WcPDpl4AaABAg',
#   'Video_Id': '5GEhN7gJjPk',
#   'Comment_Text': '"I just wanted to drop by and express my gratitude for your amazing content. Your coding tutorials have helped me level up my skills in ways I never thought possible. Thank you for sharing your knowledge with the world!"',
#   'Comment_Author': '@monesh.s6001',
#   'Comment_Published': '2024-03-16T03:59:44Z'},
#  {'Comment_Id': 'Ugz72emeEKiB4-wX0tN4AaABAg',
#   'Video_Id': 'k4MXTHwCg_4',
#   'Comment_Text': '🔥🔥',
#   'Comment_Author': '@user-zc6du1ch8i',
#   'Comment_Published': '2024-03-14T15:39:52Z'},
#  {'Comment_Id': 'UgxaU_gCkoungNZXePR4AaABAg',
#   'Video_Id': 'k4MXTHwCg_4',
#   'Comment_Text': '🎉....we are waiting for ur next video',
#   'Comment_Author': '@monesh.s6001',
#   'Comment_Published': '2024-03-14T02:57:20Z'},
#  {'Comment_Id': 'UgyF9WtEOlh0tRggjfd4AaABAg',
#   'Video_Id': 'taCYyfk9_mc',
#   'Comment_Text': 'Try it out now: https://code-jr.vercel.app\nGitHub Repo: github.com/sheninthjr/CodeJr',
#   'Comment_Author': '@sheninthjr',
#   'Comment_Published': '2024-01-20T11:06:48Z'},
#  {'Comment_Id': 'UgybAt-avhzeqQxukp14AaABAg',
#   'Video_Id': 'vpZK7vA9aaE',
#   'Comment_Text': 'Next time increase your ediotr font size and add music and also edit your videos',
#   'Comment_Author': '@gamingtitan0',
#   'Comment_Published': '2024-04-30T21:24:11Z'},
#  {'Comment_Id': 'UgxyKhUsOtvc1cBuw_F4AaABAg',
#   'Video_Id': 'vpZK7vA9aaE',
#   'Comment_Text': '????',
#   'Comment_Author': '@haikelareff',
#   'Comment_Published': '2024-01-29T16:43:03Z'}]

# %%
#get playlist details

def get_playlist_details(channel_id):
    All_data = []
    next_page_token = None
    next_page = True
    while next_page:

        request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
            )
        response = request.execute()

        for item in response['items']: 
            data={'PlaylistId':item['id'],
                    'Title':item['snippet']['title'],
                    'ChannelId':item['snippet']['channelId'],
                    'ChannelName':item['snippet']['channelTitle'],
                    'PublishedAt':item['snippet']['publishedAt'],
                    'VideoCount':item['contentDetails']['itemCount']}
            All_data.append(data)
        next_page_token = response.get('nextPageToken')
        if next_page_token is None:
            next_page=False
    return All_data

# %%
#MongoDB Connection

client = pymongo.MongoClient("mongodb+srv://originalsrabbit:mirunalini100L@cluster0.sczfzsh.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client["Y_data"]

# %%
# upload to MongoDB

def channel_detail(channel_id):
    ch_details=get_channel_info(channel_id)
    vid_ids=get_video_ids(channel_id)
    vid_info=get_video_info(vid_ids)
    com_info=get_comment_info(vid_ids)
    pl_details=get_playlist_details(channel_id)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"comment_information":com_info,"playlist_inforamtion":pl_details,
                  "video_information":vid_info})
    
    return "upload complete successfully"

# %%
insert=channel_detail("UCqnP1HkcAnueBjyKCdaoNHg")  #zebrazone, sameesha, jk, jedcal

### channel links

### zebrazone - "UC6PIKnoGw7rJnND6_jdoo5w"
### micset    - "UC5EQWvy59VeHPJz8mDALPxg"
### sameeha marium - "UCaJclHt8WiaQjbv9DY2gKjg"
### irfans view - "UCnjU1FHmao9YNfPzE039YTw"
### vj siddhu vlogs - "UCJcCB-QYPIBcbKcBQOTwhiA"
### jk - "UC_HZY9d5wJ-MEiuq6vhx8hg"
### jedcal - "UCpjLVja-gdCtElYvMmvYvYQ"

# %%
import psycopg2

def channels_table():
    try:
        mydb = psycopg2.connect(
            host="localhost",
            user="postgres",
            password="mirunalini100L",
            database="ydata",
            port="5432"
        )
        cursor = mydb.cursor()

        create_query = '''CREATE TABLE IF NOT EXISTS channels (
                            Channel_Name VARCHAR(150),
                            Channel_Id VARCHAR(100) PRIMARY KEY,
                            Subscription_Count INT,
                            Views BIGINT,
                            Total_Videos INT,
                            Channel_Description TEXT,
                            Playlist_Id VARCHAR(100)
                        )'''
        
        cursor.execute(create_query)
        mydb.commit()

        ch_list = []
        db = client["Y_data"]
        coll1 = db["channel_details"]
        for ch_data in coll1.find({}, {"_id": 0, "channel_information": 1}):
            ch_list.append(ch_data["channel_information"])
        df = pd.DataFrame(ch_list)

        insert_query = '''INSERT INTO channels (
                            Channel_Name,
                            Channel_Id,
                            Subscription_Count,
                            Views,
                            Total_Videos,
                            Channel_Description,
                            Playlist_Id
                        ) VALUES (%s, %s, %s, %s, %s, %s, %s)'''

        for index, row in df.iterrows():
            values = (
                row['Channel_Name'],
                row['Channel_Id'],
                row['Subscription_Count'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id']
            )

            try:
                cursor.execute(insert_query, values)
                mydb.commit()
            except psycopg2.IntegrityError as e:
                mydb.rollback()
                print("Error:", e)
                print("Channels values might be already inserted")

    except psycopg2.Error as e:
        print("Error:", e)
    finally:
        if cursor:
            cursor.close()
        if mydb:
            mydb.close()

# Call the function
channels_table()

# %%
import psycopg2
import pandas as pd
from pymongo import MongoClient

def playlists_table():
    mydb = psycopg2.connect(
        host="localhost",
        user="postgres",
        password="mirunalini100L",
        database="ydata",
        port="5432"
    )
    cursor = mydb.cursor()
    
    # Dropping the table if it already exists
    drop_query = "DROP TABLE IF EXISTS playlists"
    cursor.execute(drop_query)
    mydb.commit()

    # Creating the table if it does not exist
    create_query1 = '''CREATE TABLE IF NOT EXISTS playlists (
                        PlaylistId varchar(100) PRIMARY KEY,
                        Title varchar(80), 
                        ChannelId varchar(100), 
                        ChannelName varchar(100),
                        PublishedAt timestamp,
                        VideoCount int
                    )'''
    cursor.execute(create_query1)
    mydb.commit()

    # Connecting to MongoDB
    pl_list = []
    db = client["Y_data"]
    coll1 = db["channel_details"]
    
    # Fetching data from MongoDB
    for pl_data in coll1.find({}, {"_id": 0, "playlist_inforamtion": 1}):
        for i in range(len(pl_data['playlist_inforamtion'])):
            pl_list.append(pl_data['playlist_inforamtion'][i])
    
    # Creating a DataFrame from the fetched data
    df1 = pd.DataFrame(pl_list)

    # Inserting data into PostgreSQL table
    for index, row in df1.iterrows():
        insert_query = '''INSERT into playlists(
                            PlaylistId,
                            Title,
                            ChannelId,
                            ChannelName,
                            PublishedAt,
                            VideoCount)
                          VALUES(%s, %s, %s, %s, %s, %s)'''
        values = (
            row['PlaylistId'],
            row['Title'],
            row['ChannelId'],
            row['ChannelName'],
            row['PublishedAt'],
            row['VideoCount']
        )
        
        try:
            cursor.execute(insert_query, values)
            mydb.commit()
        except Exception as e:
            print("Error:", e)
            mydb.rollback()  # Rollback the transaction to prevent further issues

    # Closing the connection
    cursor.close()
    mydb.close()

# Call the function
playlists_table()

# %%
import psycopg2
import pandas as pd
from pymongo import MongoClient

def videos_table():
    # Connect to PostgreSQL
    mydb = psycopg2.connect(
        host="localhost",
        user="postgres",
        password="mirunalini100L",
        database="ydata",
        port="5432"
    )
    cursor = mydb.cursor()

    # Dropping the table if it already exists
    drop_query = "DROP TABLE IF EXISTS videos"
    cursor.execute(drop_query)
    mydb.commit()

    # Creating the table if it does not exist
    create_query = '''CREATE TABLE IF NOT EXISTS videos(
                        Channel_Name varchar(150),
                        Channel_Id varchar(100),
                        Video_Id varchar(50) PRIMARY KEY, 
                        Title varchar(150), 
                        Tags text,
                        Thumbnail varchar(225),
                        Description text, 
                        Published_Date timestamp,
                        Duration interval, 
                        Views bigint, 
                        Likes bigint,
                        Comments int,
                        Favorite_Count int, 
                        Definition varchar(10), 
                        Caption_Status varchar(50) 
                    )'''
    cursor.execute(create_query)
    mydb.commit()

    # Connecting to MongoDB
    vi_list = []
    db = client["Y_data"]
    coll1 = db["channel_details"]

    # Fetching data from MongoDB
    for vi_data in coll1.find({}, {"_id": 0, "video_information": 1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])

    # Creating a DataFrame from the fetched data
    df2 = pd.DataFrame(vi_list)

    # Inserting data into PostgreSQL table
    for index, row in df2.iterrows():
        insert_query = '''
            INSERT INTO videos (
                Channel_Name,
                Channel_Id,
                Video_Id, 
                Title, 
                Tags,
                Thumbnail,
                Description, 
                Published_Date,
                Duration, 
                Views, 
                Likes,
                Comments,
                Favorite_Count, 
                Definition, 
                Caption_Status 
            )
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        '''
        values = (
            row['Channel_Name'],
            row['Channel_Id'],
            row['Video_Id'],
            row['Title'],
            row['Tags'],
            row['Thumbnail'],
            row['Description'],
            row['Published_Date'],
            row['Duration'],
            row['Views'],
            row['Likes'],
            row['Comments'],
            row['Favorite_Count'],
            row['Definition'],
            row['Caption_Status']
        )

        try:
            cursor.execute(insert_query, values)
            mydb.commit()
        except Exception as e:
            print("Error:", e)
            mydb.rollback()  # Rollback the transaction to prevent further issues

    # Closing the connection
    cursor.close()
    mydb.close()

# Call the function
videos_table()

# %%
import psycopg2
import pandas as pd
from pymongo import MongoClient

def comments_table():
    # Connect to PostgreSQL
    mydb = psycopg2.connect(
        host="localhost",
        user="postgres",
        password="mirunalini100L",
        database="ydata",
        port="5432"
    )
    cursor = mydb.cursor()

    # Dropping the table if it already exists
    drop_query = "DROP TABLE IF EXISTS comments"
    cursor.execute(drop_query)
    mydb.commit()

    # Creating the table if it does not exist
    create_query = '''CREATE TABLE IF NOT EXISTS comments(
                        Comment_Id varchar(100) PRIMARY KEY,
                        Video_Id varchar(80),
                        Comment_Text text, 
                        Comment_Author varchar(150),
                        Comment_Published timestamp
                    )'''
    cursor.execute(create_query)
    mydb.commit()

    # Connecting to MongoDB
    com_list = []
    db = client["Y_data"]
    coll1 = db["channel_details"]

    # Fetching data from MongoDB
    for com_data in coll1.find({}, {"_id": 0, "comment_information": 1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])

    # Creating a DataFrame from the fetched data
    df3 = pd.DataFrame(com_list)

    # Inserting data into PostgreSQL table
    for index, row in df3.iterrows():
        check_query = "SELECT Comment_Id FROM comments WHERE Comment_Id = %s"
        cursor.execute(check_query, (row['Comment_Id'],))
        existing_comment = cursor.fetchone()

        if existing_comment:
            print(f"Comment with ID {row['Comment_Id']} already exists. Skipping insertion.")
        else:
            insert_query = '''INSERT INTO comments (
                                    Comment_Id,
                                    Video_Id,
                                    Comment_Text,
                                    Comment_Author,
                                    Comment_Published
                                )
                                VALUES (%s, %s, %s, %s, %s)
                            '''
            values = (
                row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text'],
                row['Comment_Author'],
                row['Comment_Published']
            )
            try:
                cursor.execute(insert_query, values)
                mydb.commit()
            except Exception as e:
                print("Error:", e)
                mydb.rollback()  # Rollback the transaction to prevent further issues

    # Closing the connection
    cursor.close()
    mydb.close()

# Call the function
comments_table()

# %%
def tables_one():
    channels_table()
    playlists_table()
    videos_table()
    comments_table()
    return "Tables Created successfully"

# %%
def show_channels_table():
    ch_list = []
    db = client["Y_data"]
    coll1 = db["channel_details"] 
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    channels_table = st.dataframe(ch_list)
    return channels_table

def show_playlists_table():
    db = client["Y_data"]
    coll1 =db["channel_details"]
    pl_list = []
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
                pl_list.append(pl_data["playlist_information"][i])
    playlists_table = st.dataframe(pl_list)
    return playlists_table

def show_videos_table():
    vi_list = []
    db = client["Y_data"]
    coll2 = db["channel_details"]
    for vi_data in coll2.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    videos_table = st.dataframe(vi_list)
    return videos_table

def show_comments_table():
    com_list = []
    db = client["Y_data"]
    coll3 = db["channel_details"]
    for com_data in coll3.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    comments_table = st.dataframe(com_list)
    return comments_table
